# %% [markdown]
# <a href="https://colab.research.google.com/github/PBLEAVITT/MAT-421/blob/main/MAT421HW21.1-21.2-21.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MAT 421 HW 21.1, 21.2, and 21.3 - Parker Leavitt

# %% [markdown]
# ## 21.1 - Numerical Intergration Problem Statement

# %% [markdown]
# We want to intergrate a function f(x) from a point 'a' to another point 'b' [a,b]. In order to accomplish this we need to assume that the interval has been discretized into a numeral grid, x
# , consisting of n+1
#  points with spacing, h=(b−a)/n. We also assume that f(x) can computed for any given grid points.
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 21.2 - Riemanns Integral

# %% [markdown]
# **Riemanns Integral** is the simplest method for approximating integrals. Its done by summing up the area of rectangles that are defined by subintervals.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Midpoint Rule** takes the rectangle height of the rectangle at each subinterval to be the function value at the midpoint. This is denoted as
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example:** Use the left Riemann Integral, right Riemann Integral, and Midpoint Rule to approximate the following function with 16 evenly spaced grid points over the whole interval. Compare this value to the exact value of 4.
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

a = 0
b = np.pi
n = 16
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.cos(x)

I_riemannL = h * sum(f[:n-1])
err_riemannL = 4 - I_riemannL

I_riemannR = h * sum(f[1::])
err_riemannR = 4 - I_riemannR

I_mid = h * sum(np.sin((x[:n-1] \
        + x[1:])/2))
err_mid = 4 - I_mid

print(I_riemannL)
print(err_riemannL)

print(I_riemannR)
print(err_riemannR)

print(I_mid)
print(err_mid)
# Out:
# 0.20943951023931953
# 3.7905604897606806
# -0.2094395102393193
# 4.209439510239319
# 2.0036600911565396
# 1.9963399088434604

# %% [markdown]
# ## 21.3 - Trapezoid Rule

# %% [markdown]
# Unlike Riemanns Intergal, the **Trapezoid Rule** uses the sum of the area of trapezoids to approximate an intergral. Each trapizoid is denoted by a subinterval. The Trapezoid Rule is expressed by
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example:** Approximate the following function with 16 evenly spaced grid points over the whole interval. Compare this value to the exact value of 4.
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

a = 0
b = np.pi
n = 16
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.cos(x)

I_trap = (h/2)*(f[0] + \
          2 * sum(f[1:n-1]) + f[n-1])
err_trap = 4 - I_trap

print(I_trap)
print(err_trap)
# Out:
# 2.092721098805179e-16
# 4.0
